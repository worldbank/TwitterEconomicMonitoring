# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/drive/1yhCfYC9Fxisoq_wXusada5Jz7zTkuLm5)

# %% [markdown]
# # Notebook #6: demographics

# %% [markdown]
# ## Description:

# %% [markdown]
# In this notebook, we will show you how to infer the gender of a Twitter user based on its user name. We will focus on Brazilian Twitter users and use public data containing Brazilian first names and their associated gender. This data can be found [here](https://gist.githubusercontent.com/augustohp/2c59ceb96e195ea375abadb311637e7f/raw/d2007f9ad2ab3d317a9b45ec65e56be741758d8c/brazilian-names-and-gender.csv).

# %% [markdown]
# ## Import modules:

# %%
import pandas as pd
import os
import re
import unicodedata
import sys
import uuid
import tweepy
from IPython.display import Image
from IPython.core.display import HTML

# %% [markdown]
# ## Data import and preprocessing

# %% [markdown]
# We first load the dataset containing Brazilian first names and their associated gender in a Pandas dataframe. You can just modify the `names_data_path` and define it as the path to this CSV file on your local machine.

# %%
names_data_path = './brazilian-names-and-gender.csv'
names_df = pd.read_csv(os.path.join(names_data_path))
names_df.head()
# Out:
#        Name Gender
# 0      Abel      M
# 1  Abelardo      M
# 2     Abner      M
# 3    Abraão      M
# 4   Absalom      M

# %% [markdown]
# We then preprocess the data by lowercasing the first names and renaming the dataframe columns. We have 6100 Brazilian first names in total.

# %%
names_df['Name'] = names_df['Name'].apply(lambda x: x.lower())
names_df.columns = ['name', 'gender']
names_df.shape
# Out:
# (6100, 2)

# %% [markdown]
# To avoid problems later, we keep only first names that at least contain two characters. This means that we discard the first name `'h'`.

# %%
names_df['len_name'] = names_df['name'].apply(lambda x: len(x))
names_df = names_df.loc[names_df['len_name'] > 1].reset_index(drop=True)
names_df.shape
# Out:
# (6099, 3)

# %% [markdown]
# Out of our remaining 6099 first names, 3537 are male first names and 2562 are female first names.

# %%
names_df['gender'].value_counts(dropna=False)
# Out:
# M    3537
# F    2562
# Name: gender, dtype: int64

# %% [markdown]
# After that, we load a dataset of tweets we previously downloaded from users located in Brazil. Because of Twitter policy, we unfortunately cannot publish this dataset. Feel free to download tweets using notebook #1 to reproduce this example with your own data.

# %%
tweet_path = './brazilian_tweets.parquet'
tweet_df = pd.read_parquet(tweet_path)

# %% [markdown]
# We limit this dataset to 1000 rows to limit computing time.

# %%
tweet_df = tweet_df[:1000]

# %% [markdown]
# ## Gender inference based on Twitter user name

# %% [markdown]
# We will now infer the gender of Twitter users based on their names. The idea is to take the Twitter user name and to look for existing first names from our database inside this Twitter user name. If one first name is found in the Twitter user name, the Twitter user is assigned the gender related to this found name.
#
# For instance, in the case of Barack Obama, if we have the first name "Barack" in our database defined as a male name, since "Barack" is contained in the string "Barack Obama", our algorithm will assign the former US president to the male gender.
#
# Obviously, this is meant as an example and it is a very simplistic approach. Therefore, inference results might not always be correct.

# %% [markdown]
# <img src="https://www.researchgate.net/profile/Tiffany_Gallicano/publication/325827578/figure/fig1/AS:638921738289154@1529342221910/Sample-Twitter-profile-and-relevant-fields.png" width="600" height="600" />

# %% [markdown]
# Image source: Wesslen, R., Nandu, S., Eltayeby, O., Gallicano, T., Levens, S., Jiang, M., & Shaikh, S. (2018, June). Bumper Stickers on the Twitter Highway: Analyzing the Speed and Substance of Profile Changes. In Proceedings of the International AAAI Conference on Web and Social Media (Vol. 12, No. 1).

# %% [markdown]
# On Twitter, user have two types of name. The first one is the "display name" (Barack Obama in the example above) and the second one is the "screen name", commonly called the Twitter handle which can be found after the `@` symbol (BarackObama here). We will look for existing first names in the display name rather than in the handle since first name and last name are separated in the former, which make finding first names easier.

# %% [markdown]
# ### Extract user handles from tweets

# %% [markdown]
# We first need to generate a list of user names we can then use to perform gender inference.

# %% [markdown]
# The first step is to generate a list of user handles. We will use the data from our Brazilian tweet dataset to generate a list of handles mentioned in these tweets. To do so, we will loop through all of the tweets from this dataset and look for user handles in each tweet. If a user handle is found, it is added to the `handles_list` list.

# %%
handles_list = list()
p = re.compile(r'@([^\s:]+)')
for i in range(tweet_df.shape[0]):
    handles_list = handles_list + p.findall(tweet_df['text'][i])

# %% [markdown]
# This way, we are able to gather 821 Twitter user handles.

# %%
len(handles_list)
# Out:
# 821

# %% [markdown]
# ### Get display name from Twitter handle

# %% [markdown]
# Now that we have a list of handles, we need to extract the display names related to each of these handles. We do this with Tweepy, by using the `get_user` method, which takes as input a Twitter handle and returns information about the related Twitter user.

# %% [markdown]
# To use Tweepy, as seen in Notebook #1, you need to define your API keys and access tokens below.

# %%
api_dict = {"API Key": "Your API key",
            "API Secret Key": "Your API secret key",
            "access_token": "Your access token",
            "access_token_secret": "Your secret access token"}

# %%
def get_auth(api_dict):
    # OAuth process, using the keys and tokens
    auth = tweepy.OAuthHandler(api_dict['API Key'], api_dict['API Secret Key'])
    auth.set_access_token(api_dict['access_token'], api_dict['access_token_secret'])

    # Creation of the actual interface, using authentication
    api = tweepy.API(auth, wait_on_rate_limit=True, wait_on_rate_limit_notify=True)

    try:
        api.verify_credentials()
    except:
        print(api_dict, ": error during authentication")
        sys.exit('Exit')
    return api

# %%
api = get_auth(api_dict)

# %% [markdown]
# Now that credentials have been identified, we loop through our list of handles `handles_list` and extract the display names related to each handle. Note that some users might have deleted their account or changed their handles. In that case, the handle is considered as invalid and the information cannot be extracted.

# %%
names_dict = dict()
for handle in handles_list:
    try:
        name = api.get_user(handle)._json['name']
        names_dict[name] = handle
    except:
        print(f'Error with handle: {handle}')
# Out:
# Error with handle: _raafarocha
# Error with handle: globoesportecem
# Error with handle: ei__frases
# Error with handle: vivimorena_makeup
# Error with handle: IramilsonManaus
# Error with handle: raayvitoria1
# Error with handle: VerdadeJH
# Error with handle: bncaique
# Error with handle: Luixpest
# Error with handle: disneyanims
# Error with handle: dissebktt
# Error with handle: jpica10
# Error with handle: memesalegres
# Error with handle: SDADHH1
# Error with handle: MlNHYUKEY
# Error with handle: murilinmebeja
# Error with handle: sccpkarev
# Error with handle: vhribeiro2
# Error with handle: joaopedro_ribas
# Error with handle: laneeoficial
# Error with handle: favelaprogresso
# Error with handle: Juverissimow
# Error with handle: cnzinhah
# Error with handle: laneeoficial
# Error with handle: _Vn_Oliveira
# Error with handle: _patrickpeixoto
# Error with handle: Nallandaaguedaa
# Error with handle: BTS_twt's
# Error with handle: rabettao_
# Error with handle: LaurinhaBonoro
# Error with handle: ElisioDado
# Error with handle: __jaol
# Error with handle: djaneslifee
# Error with handle: thelminha_assis
# Error with handle: amococada
# Error with handle: DojaCatBra
# Error with handle: ninztsfe
# Error with handle: wtfhestia
# Error with handle: UNlVERSITARIA
# Error with handle: 365decepcoes
# Error with handle: AllanWelder
# Error with handle: Karol15ayne
# Error with handle: Djgordaosjm
# Error with handle: vitorpsilvaa
# Error with handle: ianittoo
# Error with handle: Mayssers1
# Error with handle: ChartTXT
# Error with handle: James_Santos_23
# Error with handle: coronavirusnobr
# Error with handle: thelminha_assis
# Error with handle: Surtanaofofinha
# Error with handle: cordiolibarry
# Error with handle: brendonfresno
# Error with handle: vinyciusliima
# Error with handle: _deejayume
# Error with handle: jv_cunh
# Error with handle: avocandies
# Error with handle: thelminha_assis
# Error with handle: memesalegres
# Error with handle: romulosousi
# Error with handle: thelminha_assis
# Error with handle: scenesari
# Error with handle: cirneymarr
# Error with handle: szjeonn
# Error with handle: kamyllevm
# Error with handle: astaribe
# Error with handle: b7nferreira
# Error with handle: aanarafa
# Error with handle: certonejo
# Error with handle: man_dioquinha
# Error with handle: MlkRevoltado157
# Error with handle: demetriamidias
# Error with handle: crfgb2m
# Error with handle: da_Pra_Velho
# Error with handle: metflixi
# Error with handle: thelminha_assis
# Error with handle: rebello_ac
# Error with handle: levydourado2
# Error with handle: cris_direita17
# Error with handle: hxsnd
# Error with handle: Cruzeiro…
# Error with handle: hollyoldcharts
# Error with handle: juu_marianne
# Error with handle: heloisaxavier_
# Error with handle: certonejo
# Error with handle: conservador222
# Error with handle: James_Santos_23
# Error with handle: nu_talo
# Error with handle: edugrassii
# Error with handle: BTS_twt's
# Error with handle: thelminha_assis
# Error with handle: RaniRF2000
# Error with handle: imkned
# Error with handle: garotttinha
# Error with handle: Natthanollvr
# Error with handle: Age1P4u10S
# Error with handle: Milly_bj1
# Error with handle: andcwt
# Error with handle: novinhosdofb
# Error with handle: Reiribeiro04
# Error with handle: emilyssnc
# Error with handle: ShockWaveRadio_
# Error with handle: fabifbbr.
# Error with handle: opropriopontes
# Error with handle: visa…
# Error with handle: gtatekawa
# Error with handle: szjeonn
# Error with handle: titianaty_
# Error with handle: ouiludida
# Error with handle: laneeoficial
# Error with handle: ignhy_b
# Error with handle: Jessica_nascixx
# Error with handle: kyotodaydream
# Error with handle: rashindio
# Error with handle: ENOi_Member_twt
# Error with handle: IceCreamyn
# Error with handle: pkjiwin
# Error with handle: sahdfranca
# Error with handle: heyy_lusion
# Error with handle: StevePi51896213
# Error with handle: DesgracaVintage
# Error with handle: marquesa_98
# Error with handle: ,
# Error with handle: marinaviruss
# Error with handle: BTS_twt)
# Error with handle: dribarros1898
# Error with handle: acid6host
# Error with handle: vittorbarros
# Error with handle: bpache_
# Error with handle: arieleoliv
# Error with handle: itsmardybum__
# Error with handle: laimuniz_bjj
# Error with handle: moonmirtx
# Error with handle: thelminha_assis
# Error with handle: ChrisStrokesX8X
# Error with handle: medmariac1
# Error with handle: Bela_Rosa_
# Error with handle: coronavirusnobr
# Error with handle: thunhara22
# Error with handle: itsrodrigs
# Error with handle: _Nicschneider
# Error with handle: brgomezz01
# Error with handle: atenanarcisista
# Error with handle: kamalinoski
# Error with handle: dannygommess
# Error with handle: dinahcomenta
# Error with handle: dahmowarts
# Error with handle: certonejo
# Error with handle: vinitxvares
# Error with handle: HeyPacheco_
# Error with handle: BacoExudoBIues
# Error with handle: 220_171
# Error with handle: vittorbarros
# Error with handle: Brunoofc22
# Error with handle: BiaAndradeOfc
# Error with handle: thelminha_assis
# Error with handle: laneeoficial
# Error with handle: rmsadistic
# Error with handle: ofutebolnews
# Error with handle: aannavf
# Error with handle: graziilindona
# Error with handle: AelissonS
# Error with handle: mcgowanflower
# Error with handle: LHomenchuk
# Error with handle: MatheusAndradd1
# Error with handle: davihen1
# Error with handle: _baarteli
# Error with handle: neragay_
# Error with handle: niggazblack123
# Error with handle: Gomessfc07
# Error with handle: PerfectPictu
# Error with handle: DailyKenshiro
# Error with handle: lxxzmmgm
# Error with handle: gabiisousa04
# Error with handle: laysa_melissa49

# %% [markdown]
# The results are saved in a dictionary containing:
# - the display names as keys
# - the handles as values:

# %%
names_dict
# Out:
# {'Samuel Nascimento💯': 'SamuKNascimento',
#  'The QuasiEconomist Formerly Known As Caet': 'CaetCaetano1',
#  'Maria Oaquim': 'mariaomed',
#  'jhony': 'joaocgvitor',
#  'ju': 'eaixu',
#  'Gaby': 'Gabyspedroso',
#  'espiã russa': 'agressivictor',
#  'viciada em BIN para todas as mulheres': 'pekibete',
#  'se mulher goza pq homem n engravida': 'tisgopjl',
#  'Francisco De Laurentiis': 'f_delaurentiis',
#  'SE Palmeiras': 'Palmeiras',
#  'nemseioqtofzdd': 'Carvalho_joaoj',
#  'Lare': 'laressa',
#  '☭Lisa Débora Indarráus🏡 ♀️ 🏳️\u200d🌈🤘🏼': 'passarosErosas',
#  'Reumalho': 'reumalho',
#  'Kamis.': 'kamisfariias',
#  '烤肉君KoRu': 'korukun',
#  'Danny 🌹': 'Danypulper',
#  'vivi morena': 'vivimakeup5',
#  'Lorena⭐️': 'badgallore',
#  'PetitAbel #BBB21': 'petitabell',
#  'Tífany': 'tifanyfaner',
#  'Isaque Morais': 'isaquemorais6',
#  'Vera Magalhães VACINA JÁ 💉': 'veramagalhaes',
#  'comentarista do bbb': 'maaferocha',
#  'loló': 'loomarcal',
#  'Rayssa Olivetti': 'RayssaOlivetti',
#  'Bot Sentinel': 'BotSentinel',
#  'Thomas Santana': 'thomassantanas',
#  'camaleão furioso': 'galacticbbru',
#  'Meu nome não é Alice': 'i_gor',
#  'Joice Hasselmann': 'joicehasselmann',
#  'louie ponto': 'louieponto',
#  'Bernardo Mello Franco': 'BernardoMF',
#  'Aline Lopes': 'alinecarolinelr',
#  'Bichinhos fofinhos pra quem ta cansado de política': 'BichinhosFB',
#  'cantasamba ✊🏿✊🏾✊🏽': 'CantaSamba',
#  '𝖍𝖒𝖉𝖗𝖊𝖘𝖘𝖆': 'Andmach1818',
#  'gabriela': 'nichelekkkk',
#  'princesinha sofia': 'sofperillo',
#  'GirlSay🔞': 'girlsay2013',
#  '★ Kami, o vaga(y)lume ★': 'Hakai_no_Hate',
#  'Guga Chacra': 'gugachacra',
#  'clara': 'claraadinizz',
#  'Jeff Atwood': 'codinghorror',
#  "il vento d'oro": 'Venanshurikin',
#  'Lucas Rangel': 'LucasRanngel',
#  'bia': 'beatrizcaiadoo',
#  'Lari Brum': 'LarissaBrum_',
#  'João Doria': 'jdoriajr',
#  'sardinha': 'risardinha',
#  'china;': 'chines_b',
#  'Portal Terça Livre': 'tercalivre',
#  '𝑱𝑼𝑼𝑱': 'ju_romoda',
#  'rô': 'roohdela',
#  '+a PAI EM DOBRO': 'maisa',
#  'Victorino': '10crfJ',
#  'Política Estadão': 'EstadaoPolitica',
#  'Rafa': '_alvx9',
#  'aninha': 'krlannes',
#  'Vanessa Brasil': 'vanessa_bs24',
#  'CNN Brasil': 'CNNBrasil',
#  'Balta™': 'balta1_',
#  'Rafaela': 'jessicaarafa',
#  'Justin Timberlake': 'jtimberlake',
#  'Fernando Alvarenga': 'fer',
#  'rafa 🌋': 'porrafaellaaaaa',
#  'Verso Sertanejo': 'VSertanejo',
#  'Juliane Melo': 'juliianemelo',
#  'Gaab': '_gaabsilva2',
#  'bravo✨': 'Br4v0Bru_',
#  'dora': 'isadoramilano',
#  '/quietinha': 'gabrightness',
#  'boca de sopa 𓆏': 'mininumatheus',
#  'só rafi': 'rafibadz',
#  'Kinho #FVCKFIUK': 'thisococa',
#  'Acorsi': 'J_Acorsi',
#  'davi sabbag': 'davisabbag',
#  'urizinha trovoada': 'uriassnake',
#  'gisele': 'jpmotaaa',
#  'princesa saudita': 'marhabati',
#  'Let 🤡': 'leticiasilb_',
#  'Nathbru': 'natthbruna',
#  'Viadinho Comunista': 'yannsx_',
#  'Mille💖': 'baixinha_ruiva2',
#  'TikTok Brasil': 'TikTokBrasil',
#  'Joyce sarti': 'JoyceSarti2',
#  'jean 🇮🇩': 'jeantuness_',
#  'Felipe Santiago 😷🏠': 'fsantiagoisdead',
#  'gab': 'Gabsntoss',
#  'Ge': 'aGesilane',
#  '🦋': 'xxzbia',
#  'joice': 'joicewx',
#  'bu': 'brunacarrv',
#  'Rafael Lange #OrdemParanormal': 'cellbit',
#  'Trecho de Pagode 🎧': 'pagodeiro_citou',
#  'jeh👩\u200d👧🦄🌺': 'Jessica39707788',
#  '𝕮𝖆𝖊𝖙𝖆𝖓𝖔𝖔': '_Caetanoolucas',
#  'Syntrophus': 'syntrophus',
#  'Felipe Prior': 'felipeprior',
#  'Werneck☇': 'escuriin',
#  '▀▄▀▄▀ Paquita Preta ▀▄▀▄▀': 'cacobapt',
#  'Ygor Costa': 'ygscosta',
#  '👑 Natalia Starr 👑': 'NataliaStarr93',
#  'HEARTLESS': 'batomv3rmelho',
#  'BTS & Books⁷': 'magicshopbooks',
#  '𝚃𝚑𝚊𝚒𝚜𝚜𝚊 ꧂': '_thaissamorais',
#  'ℓυίsα': 'luisascampos_',
#  'adm diogo defante🍎': 'defantediogo',
#  'Rei🥈': 'jsmarley22',
#  'Fernando': 'YaeNando',
#  '𝗠𝗢𝗨𝗥𝗔': 'moura_aliny',
#  'mateus': 'alamoju',
#  'Black Mamba': '_pqpvoces',
#  'Tom Fletcher': 'TomFletcher',
#  'shélin': 'ShelinAlves',
#  'Eudes Gomes': 'eudes_gs',
#  'Jon': 'DBem',
#  'gg #10 stan': 'guxllaryen',
#  'luis 🌎': 'ferrarilh',
#  'Cecilia': 'marrriacecilia',
#  'carolinE-seu jorge.mp3': 'krolanaja',
#  'Charles Bukowski': 'charlebukowski',
#  'Talyta 🌵': 'Aladastiana',
#  'Anne Lottermann': 'AnneLottermann',
#  'Tiago Scheuer': 'xoia',
#  '🦋✨⛓ ɐpuɐuɹǝɟ': 'insthedxrk',
#  'Mrs. Petty': 'NICKIMINAJ',
#  'isabela': 'ornitorrincon',
#  '富士見ファンタジア文庫公式/2月20日新刊発売': 'fantasia_bunko',
#  'greys anatomy': 'magicxgreys',
#  'SecretAgent': 'bethxerem',
#  'Maria do Rosário': 'mariadorosario',
#  'Globo Rural': 'Globo_Rural',
#  'sol': '_vcaroline_',
#  'Gabi Lopes': 'anaalopesz',
#  'ber có': 'BerquoMarco',
#  'n o z z e n': 'ThallesNozzen',
#  'Eduardo Bolsonaro🇧🇷': 'BolsonaroSP',
#  'Flavio Bolsonaro': 'FlavioBolsonaro',
#  'Carlos Bolsonaro': 'CarlosBolsonaro',
#  'Jair M. Bolsonaro': 'jairbolsonaro',
#  'calegari': 'gui_calegari13',
#  'cansada de existir': 'lhamarezende',
#  'Ana Flor': 'Tdetravesti',
#  'Dora Figueiredo': 'dorafigueiredo',
#  'PorqueJesusteama': 'PJesusteama',
#  '𝕷𝖎𝖛𝖎𝖆': 'ligaaivil',
#  '_Sabrinamb': '_sabrinamb',
#  'caro is proud of liv, louis and taylor': 'louiswift28',
#  'seu amigo cleyto': 'cleytxn',
#  'juleo': 'ounojo',
#  'marrento': 'Yurisdr1',
#  'Tamires De Paula': 'tamires_scpaula',
#  'la 🅱️andoleira': 'jukiaspfc',
#  'Branko Milanovic': 'BrankoMilan',
#  'Você se foi ✪': 'vocesefoii',
#  'caick': 'craiskc',
#  'Alef Rodrigo': 'alefrodrigo93',
#  'ً': 'jikookpictures',
#  '𝐆𝐚𝐭𝐢𝐭𝐚': 'emile_tt',
#  'TOMORROW X TOGETHER': 'TXT_members',
#  'MC Nau': 'mcnauu',
#  'sara': 'srmkll',
#  'amy ❥': 'arianwcloud',
#  'FerNando 🦅': 'Chiappin_',
#  'Roberta': 'romuzae_',
#  'Bianca': 'biwosch_',
#  'Maria Rita': 'MariaRita',
#  'Seba de Natal ☃️🎄': 'seba_m762',
#  'Wesley Safadão': 'WesleySafadao',
#  'Mariana': '_marianavitoria',
#  'Oliveira 🌵': 'Oliveiirawallac',
#  'ℭristal, ɴᴇᴏᴄᴀɴɢᴀᴄᴇɪʀᴀ ᴇ ᴇᴄᴏᴛᴇʀʀᴏʀɪꜱᴛᴀ': 'theonlycristalj',
#  '𝙗𝙖𝙩-𝙤𝙢𝙞𝙣𝙞𝙩𝙧𝙞𝙭': 'bruh__ortiz',
#  'Luan': '_soaresluan',
#  'Karinená': 'Karinesanttosf1',
#  'Bangtan News Brasil ⟭⟬ ⁷': 'BTSNewsBrasil',
#  'Jr. Rocha 🦈': 'Jr_Machado1903',
#  'Neymar Jr': 'neymarjr',
#  'alienada': 'yasminalvesilva',
#  'ᴄᴀɪᴏ': 'Barbosacaio19',
#  'XLK': 'xalinska',
#  'bibi Ahh +Braba!!': 'baragrielah',
#  'julia alve$': 'juliaaaa_alves_',
#  'call me cenorita': 'likeazombie',
#  'Celinha': 'celinha_25',
#  '𝔡𝔞𝔫𝔦𝔢𝔩': 'sensevittar',
#  'júnior': 'Junhores',
#  'gabi': 'hi_gabss',
#  'madu': '_m4du_p',
#  'jones da silva': 'J_GREMIO_FBPA',
#  '(B)araqueiro': 'araqueiro',
#  'Folha de S.Paulo': 'folha',
#  'Adrielle': 'Adrifeitosa1988',
#  'laurinha': 'EvelynLaura11',
#  'Claudio Silva': 'claudiobolero',
#  'fulana': 'paloma_mic',
#  'clarissa': 'clapiclapiclapi',
#  'juliana': 'julianatrez',
#  '🇧🇷 𝕌𝕓𝕚𝕣𝕒𝕥𝕒𝕟 𝕁𝕠𝕣𝕘𝕖 𝕀𝕠𝕣𝕚𝕠 🇮🇹': 'biraiorio',
#  'A paz de Cristo! ✝️': 'A_Paz_de_Cristo',
#  'best of kevin atwater': 'bestofatwater',
#  '𝘺𝘢𝘴⇜ ⁷🐯': 'iloveutaeh',
#  'Coruja BC1🦉': 'corujabc1',
#  'vitao': 'vencernavida_',
#  'Demi Lovato Charts': 'dlcharts',
#  'Elis Amâncio em 🏠': 'elis_amancio',
#  'Ana Paula Valadão Bessa': 'anapaulavaladao',
#  '📂': 'hogwartsIibrary',
#  'Julieta 🌙': 'juliabeatriz026',
#  'zambolim': 'alfzambolim',
#  '': 'bernardopkuster',
#  'Michele Araújo Clube Turismo': 'ClubeMichele',
#  'Gio Bassalo': 'giovannabassalo',
#  'Trouxa': 'uaitrouxa',
#  'nunca usei drogas e nunca vo usar dnv': 'useicrackkk',
#  'Suellen': 'suellenporra',
#  'Estrela': 'Carol_Visentim',
#  'Isa✨': 'Isabela__Mendes',
#  '🇳🇱 FAVELA NOVA HOLANDA 🇳🇱': 'favelanhofc',
#  'memes inteligentes': 'memeinteligente',
#  'Arthur Weintraub': 'ArthurWeint',
#  'viado autêntico': 'victxxiury',
#  'Kamila': 'kamila_rn_',
#  'geo': 'georz_',
#  'Lula': 'LulaOficial',
#  'JD \uf8ff': 'jadsonD1',
#  'DA HURLEY . 😏': 'Jonathan_Inaci',
#  'SÓ PAPO NA LÓGICA❗': 'paponalogica_',
#  'murilo': 'mulliror',
#  'Nikolas Bottós': 'nikolasbottos',
#  'STF': 'STF_oficial',
#  'seu amigo alecrim, analista do BBB': 'alcrsk',
#  'Gêmeos': 'AquiGemeos',
#  '⛓estou em casa⛓': 'lgsilva237',
#  'bianca': 'BiancaTriches',
#  'ribeiro': 'casquinha_cf',
#  'CONMEBOL Libertadores': 'LibertadoresBR',
#  'Dalila silva': 'dalilasilva__',
#  'debora lage': 'deboralagee',
#  'Todo dia um golaço do flamengo': 'golscrf',
#  'maicon reserva': 'maiconkusterkkk',
#  'luscas': 'luscas',
#  'S e n s i t i v e 不同': 'HAHAHAKlLLME',
#  'thaysa': 'ThaysaMc',
#  'Paulista': 'leozinng',
#  'The Smiths Lyrics': 'smiths_lyrics',
#  'morena': 'clarisimolesi',
#  'Konoha Universe': 'KonohaUniverse',
#  'lícia': 'alicianevees',
#  'livA': 'liviadotcom',
#  'POCAH 🍑': 'Pocah',
#  'Ret': 'FilipeRet',
#  'ؘ': 'euphwriaw',
#  'Igor Aleixo': 'IgorAleixo3',
#  'Júlia Gomes': 'juugmss',
#  'Gifs Safados': 'GifSafadosOfc',
#  'Nazaré Amarga': 'NazareAmarga',
#  'E!♨︎': 'ehmawi',
#  'a menina q tirou mil na redação': 'beatrizzCostaP9',
#  'gatinha consumista': 'afadalatina',
#  'Luana Pandoca 🔮': 'pandocatarot',
#  'Amanda': 'amanda_andrig',
#  '𝑃𝑎𝑝𝑝𝑖 𝑋𝑎𝑣𝑖 𝑀𝑜𝑟𝑒𝑛𝑜 1️⃣3️⃣ ★ 🏳️\u200d🌈': 'AkaFigliollo',
#  'Sérgio Alves🚩 #ForaBolsonaro': 'SergioAlvesRio',
#  'Haru 🪐 cr: acotar': 'harunookami',
#  'derik': '_magrela__',
#  'menina veneno meu peito é pequeno': 'blogueirinhaofc',
#  'Mari': '_mariftx',
#  'memes para pessoas tristes': 'memedepressivos',
#  'tom_apaixonado': 'tomapaixonado',
#  'Lorena Nascimento': 'lorenanseabra',
#  'gabizinha✨': 'ggabi_2',
#  'Sophie Kwidsan🇺🇸': 'kwidsan',
#  'ɴɪᴄᴏʟᴀs ⚔️': 'nicolasnp_',
#  'batatinha': 'Lucas_paivaaaa',
#  'PSDB 🇧🇷': 'PSDBoficial',
#  'Bruno Covas': 'brunocovas',
#  'Pedro Hales': 'pedrohales',
#  'tatuadoor, emo, fã de fresno': '011vasconcellos',
#  'Alininha ✨': 'AlineWelter2',
#  'madame "ZEBRA”': 'sidoka_fc',
#  'doka "ZEBRA"': 'npsidoka',
#  'Senador Angelo Coronel': 'angelocoronel_',
#  'Carlos A. M. Afonso': 'lucianoayan',
#  'Biólogo Henrique o Biólogo das Cobras': 'BiologoHenrique',
#  'Atila Iamarino': 'oatila',
#  '🇧🇷 Camile Pacheco 🇧🇷': 'camilepacheco',
#  'Janaina Paschoal': 'JanainaDoBrasil',
#  'Alexandre Shazzam': 'alefrota77',
#  'Ronaldo Caiado': 'ronaldocaiado',
#  'Wilson Witzel': 'wilsonwitzel',
#  'Lasier Martins': 'lasiermartins',
#  'Modesto Carvalhosa': 'CarvalhosaMo',
#  'Luis Nassif': 'luisnassif',
#  'Pedro kauan': 'KauannPedro',
#  'ste': 'haveumetsteph',
#  'chart data': 'chartdata',
#  'mikannn': 'hey_mika',
#  'ZÉ PELINTRA 🎲♠': 'vulgodonato_',
#  'Dilsinho': 'DilsinhoOficial',
#  'fael': 'fael_terra',
#  'carla morais': 'ca_moraiss',
#  'Carla Bartiê': 'Carlota_E',
#  'titi müller': 'titimuller',
#  'Simultaneamente, porém depende': 'karol_moreno',
#  '𝐰𝐚𝐭𝐨𝐧𝐢𝐤𝐢': 'watoniki',
#  'Carolina Saar 🇧🇷🇮🇱🇩🇪': 'carolina_saar',
#  'G1 - Rio': 'g1rio',
#  's.e.a': 'zckturned',
#  'Natica': 'nathcpereira_',
#  'é a glutth po lol': 'Glutth',
#  'Elis': 'maisfelis_',
#  'Mini': '_jvmini',
#  'Coração Peludinho': 'abarretinhojr',
#  'Antonio Tabet': 'antoniotabet',
#  '𝑲𝒂𝒂𝒉 🍒': 'SunshineRare_',
#  'O POVO Online': 'opovoonline',
#  'Joey Lee ♱': 'josephleemc_',
#  'Fetiche': 'fechinenicolas',
#  '𖤐⛓️ 𝖆𝖓𝖎𝖓𝖍𝖆 𝖊𝖒𝖔 ⛓️𖤐': 'sweetcarstairss',
#  'akila': 'akilaisnotsoup',
#  '𖥻 Ɲє̂ѕѕα៹⁷🎸': 'ggukdarling',
#  'alex': 'eualexgomess',
#  '✨💫': 'Lays74103805',
#  'baseado em afetos reais': 'afetosreais_',
#  'Joli': 'joli1308',
#  'calango': 'Calango',
#  'preciso de férias': 'patrickmageski',
#  'nacarlaaaa': '_naacarla',
#  'SEXFLIX 🖥🔥': 'SexoIogo',
#  'wendy': '_euwendy',
#  'MATHEUS': 'katyskettle',
#  'insert name here': 'nathaliaterra',
#  'Revista Bula': 'revistabula',
#  'medeiros': 'gabmedei',
#  'K': 'slacris_',
#  'Tatiane Melo': 'wtatimelo',
#  'yuri oliveira': 'yuriolivs',
#  'NABLUNT': 'nablunt_',
#  'Tibeça!': 'Theduardo01',
#  '𝕔𝕠𝕔𝕠𝕥𝕒🌴': 'selenevmb',
#  'Beatriz': '_shadowfirst',
#  'vivi 🌞': 'vivitorlando',
#  'Gabriela': 'Gabriellaa_cg',
#  'isa brun': 'isaabrun',
#  'Trouxinha': 'euotrouxa',
#  'd': 'adoretruly',
#  '☾': 'Liviacantanhed2',
#  'Thainá': 'thai_cstd',
#  'Gizelly Bicalho 🌪': 'gizellybicalho',
#  'Letícia Bortolotti': 'leti_bortolotti',
#  '𝐀𝐛𝐞𝐥𝐢𝐳𝐚𝐝𝐨 🐝': 'thiagowalker',
#  'Breno Reinert': 'reinert__',
#  'ph': 'Pedro_Hwt',
#  'ℓ𝖚𝖈𝖆𝖘 pdc': 'souzalc3_',
#  'THAILANE': 'ssthailane',
#  'Silvio Grimaldo': 'silviogrimaldo',
#  'zubumafu': 'itscholibaby',
#  'FutPapers': 'futpapers',
#  'luan': 'launcastro',
#  'greg flamenguista': 'eduardatds',
#  'pi coca': '_picoca',
#  '𝕴 𝖆𝖒 𝖆 𝖇𝖎𝖙𝖈𝖍': 'leoodyas',
#  'DOC': 'SamuelDoc_1',
#  'nathalia': 'nspreigschadt',
#  'NICKI MIANJ UNLOCKED': 'nmchartss',
#  'A BRABA TEM NOME': 'eumcmarcelly',
#  'felipe': 'felipezando',
#  'malice': 'mariaalicee27',
#  'marlon': 'crf_marlon10',
#  'Marcos Almeida': 'omarcosalmeida',
#  'toleda': 'lucxstoledo',
#  'fifi': 'fscavaza',
#  'ytalo': 'Ytalofelix2',
#  'Josias Teófilo': 'josiasteofilo',
#  'Ｃａｉｏｃａｌｏｔｅｒｉｚａｄｏ': 'vaimuleque_',
#  'ivete 🇪🇪': 'caaraffini',
#  'Totti Vasconcelos': 'souaquaman',
#  'Ingrid': 'gnorzinha_',
#  'Justin Bieber': 'justinbieber',
#  'Michelle H.': 'Michkpop16',
#  'VAV': 'VAV_official',
#  'Cash.VAV': 'VavCash',
#  'Estêvane Oliveira': 'estevaneoliver',
#  'Maiana Bernardes': 'maianabernardes',
#  '𝔾 𝕣 𝕖 𝕥 𝕒 🍑 𝟟 𝟘 𝟘 𝕂': '6blogger',
#  'y': 'yasfrrr_',
#  'luana🌜': 'luludapomeranha',
#  'Lucas CTM 👽': 'gritabokao',
#  'Felipe Neto': 'felipeneto',
#  'bbbiel': 'gabirelsss',
#  'Sodré, humor q ñ te faz rir 𓆏': 'Sodre77',
#  'Bandida😝': 'Rafaela9312',
#  'Lucas': 'lucaxarruda',
#  '𝑨𝒍𝒆𝒔𝒔𝒂𝒏𝒅𝒓𝒂': 'Leleeh_bjss',
#  'Batima do Mancini': 'excabeludin',
#  'Mileju': 'camilejoanaa',
#  'Rafa Kalimann ✨': 'rafakalimann_',
#  '💭': 'taekookmemories',
#  'sarahafonseca': 'sarahafonseca',
#  'BBO MÍDIA⁷': 'btsbrasil_offc',
#  'vivendo e aprendendo só n sei o q': 'ddnr0',
#  'petucia comissões abertas𓆏': 'petuciamesmo',
#  'Paulo Bonfim': 'pbonfimjr',
#  'Maria Perplecta': 'MariaSorella',
#  'Vitor Hugo': 'furtadovitor_',
#  'jotavê': 'thejotave',
#  'Alessandro Loiola': 'AlessandroLoio2',
#  'Filipe Ret': 'Filiperetbrow',
#  'jana': 'Janainedutras_',
#  'alsjkaja': 'chaotichllz',
#  'Sonho De Ser Mãe 👪💍👶': 'maedesonho',
#  'Damares Alves': 'DamaresAlves',
#  'bea៹⁷🌶️': 'pjm_pepper',
#  'dublê 🏋🏻\u200d♂️🐺🎮': 'maraisaduble',
#  'Governo do Ceará': 'GovernoDoCeara',
#  'yasmin 📍': 'Yasmin_6968',
#  'DJ MT 22 🇩🇪': 'EmiteSilvaa',
#  '𝕙𝕠𝕜𝕒𝕘𝕖': 'sad_steh',
#  'Mr. Rager 🌻': 'matheusgarzza',
#  'myllena dalla': 'stwrtdalla',
#  '🆁🅴🆅-9999': 'Rev_9999',
#  'y2': 'yury_crf',
#  'Luiza': 'luizaoliv__',
#  'sorvetin de pistache // mundinho Caio BR': 'empowereddlixo',
#  'bê': 'aabelardoo',
#  'destiny misses the oa': 'theOAagenda',
#  'nath': 'nathmirandss',
#  'Aman da': 'ruivaazeda',
#  'dmscno': 'luandamasceno',
#  'Carol🦋': 'CarolBarcelos77',
#  '🍁 Erva Sagrada 💨': 'sagradaerva',
#  'Antonio Valdetaro': 'avaldetaro',
#  'Caroline De Toni': 'CarolDeToni',
#  'Pornstars addict': 'sexualletter',
#  'Romi Rain': 'Romi_Rain',
#  'alvaro': 'alvxaro',
#  'vini': 'esquizochanel',
#  'júlia': 'juliacastro_m',
#  'miin': 'jhkgalaxy',
#  'manhosa☹︎ ☻︎': 'szzjt',
#  'menozin😈': 'belmonte_',
#  'maju': 'majullems',
#  'duda fracassada': 'dudagueddes',
#  'faye': 'yeosangmon',
#  'Harley Alves': 'usernameharley',
#  'a mimi': 'alencarmimi',
#  'INSTA 📸 : @CHDIFICIL': 'CHDIFICIL',
#  'Mav & Robô® (Trump Censured)✪': 'Real_TMavPlus',
#  'paulo junior': 'paulo__junior__',
#  'EmbaixadaResistência': 'emb_resistencia',
#  'kivelzinha': 'becca_kivel',
#  '⚠️tal da gabi caldeira': 'gabicaldeira__',
#  'Namizinha 🌼 #FreeVictor': 'TeAmoBangtanS2',
#  'Malvina': 'anacronices',
#  'MC Carol': 'mc_caroloficial',
#  'Fiaspo': 'Fiaspo',
#  '+a ᶠᵃᵏᵉ': 'maisafake',
#  'Guilherme Fiuza': 'GFiuza_Oficial',
#  'oh homi😎': 'kayancp_',
#  "dee. | harry's day ⭐": 'harrymoonchild',
#  'Nossos Orixàs🕊 #40tenadoAxé': 'NossosOrixas',
#  'Marcus ¹³ ᶜᵃᵐ': 'MarcusSantos__',
#  'redfish': 'redfishstream',
#  'Rainan Oliveira': 'rainan_oliveira',
#  'Brother Esquizy | 🎓⭐🦋 | #BBB21': 'esquizopoc',
#  'Ry 🍀🍃': 'staregulus',
#  'Gabriela 🦋': 'ricardigabi',
#  'Ďiaba 🔥': 'oliivernessa',
#  'Kamilinha': '__Selhorst__',
#  'let': 'letsemaltura_',
#  'Joana Dabb': 'joanadabb',
#  'Alan Lopes': 'AlanLopesRio',
#  'VEJA': 'VEJA',
#  'Ron Eisele': 'ron_eisele',
#  'herick🤠🚜': '_herickvinicius',
#  'mundinho pocah 🍑': 'Luskas2442',
#  'dudinha': 'madureeis',
#  'Querida💋': 'queridaporelas',
#  'Futmais': 'futtmais',
#  'L': 'itsliviaz',
#  'sacuL: Dezativado': 'losketa',
#  'tralli🌻': 'TralliAndressa',
#  '╤╾': 'ashley_tralli',
#  'maju:)': '_majuoo',
#  'Marcelo Rubens Paiva': 'marcelorubens',
#  'ECBruno Sant': 'BruReisSant',
#  'Perfectly Cut Screams': 'AAAAAGGHHHH',
#  'bia f': 'anabclerfraga',
#  'Tracklist': 'PortalTracklist',
#  'marquim😜': 'marcopaulot',
#  'Julia Nascimento': 'NascimentJu',
#  'Ports 👑': 'portelinhajj',
#  '🐍': 'larrubianatasha',
#  'Luiz Henrique': 'luizinhooo_h',
#  'camis': 'camisebersol',
#  'M.pinheiro': 'Matheus3Pin',
#  'ferreira 🎱🤠': 'FerreiraAnna15',
#  'kerellyn': 'kerellyn5',
#  'Fernando Nisio': 'Fernandonisio',
#  'gatinha 🦈': 'ninamaiat_',
#  'kaique': 'kaiquebritor',
#  'hbday harry styles': 'icehfeyre',
#  'Arrocha': '_biarrocha',
#  'GL': 'GLrvdx',
#  'Típica mulher': 'Danielapy28',
#  'ianzito': 'puunxx',
#  'mafêia': 'mfernandafds',
#  'Frases': 'UmFilosofoCitou',
#  '.:.Cadelinha de Priscila Senna.:.': 'coviiid666',
#  'mari': 'marigonzalez',
#  'Big Brother Brasil': 'bbb',
#  'Tim Maia Brasileiro': 'BabuSantana',
#  'Projota Di Penteado🛸': 'realtelleszin',
#  'bs?ubs?usb': 'bsfranc',
#  'Corrupção Brasileira Memes- CBM': 'CorrupcaoMemes',
#  'Dami 🍃 🏹': 'Damianizando',
#  'Ayla': 'ayla_rodriguess',
#  'mylënä': 'myl_oliveira',
#  'Flávio Dino 🇧🇷': 'FlavioDino',
#  'Maressa Lopes': 'lopesmahs',
#  'faela': 'Rafaevoraa',
#  'Gabriel Norberto': 'StultiferaNav1s',
#  'tri rebaixado': 'Kleutoris',
#  'May 🎧 Projota Supremacy': 'maybyreal',
#  'jonasluiz': 'jonasluiz88',
#  'Henry Darko': 'hddarko_',
#  '𝕺𝖘𝖈𝖆𝖗': 'oscarneww',
#  'Lia Clark ✨': 'liaclarkoficial',
#  'Pepita | Assistam e Ouçam #Recruta': 'pepitaofc',
#  'Nick': 'Nicolas_L0pes',
#  'Evellyn ✨': 'Evellyn0602',
#  'matheus': 'mthsexplicit',
#  'OLD': 'oldvx',
#  'ollivia 🔅': 'olliviapereira',
#  'Governo do Brasil': 'govbr',
#  'fatos ex': 'FatosEx',
#  'Nemo🇧🇷': 'YuriMAlves',
#  'Chico - mundinho caio caloteiro': 'fr4nchico',
#  'maria nas nuvens 📖☁️': 'mariaclara_b',
#  'João Lucas 🏳️\u200d🌈🇧🇷': 'joaolucasjPT',
#  '𝑀𝑎𝑛𝑝𝘩𝑜': 'vitoramayer',
#  'Casal Falando': '1Casalfalandu',
#  'lobapreta': 'mulamank',
#  'GorgeousMushroom': 'GMMUSHROOM',
#  'michael clifford': 'Michael5SOS',
#  'Rafinha': 'CostalimaRafael',
#  'Sergio Moro': 'SF_Moro',
#  'julinha': 'juliacsouza_',
#  'hourly irene': 'hourlyrene',
#  'lisa': 'lisabarcelox',
#  'LADROES SE FUDENDO': 'ladraosefudendo',
#  'Reginald Hudlin': 'reghud',
#  '2.0': 'minyardists',
#  'gabriel': 'valhagabiru',
#  'renão': 'renao',
#  'chagas': 'thaischagasz',
#  'LOLA 🔥': 'FabinhoAlb20',
#  'Maria': 'mariiabem',
#  'Kamui': 'eogabrieldiego',
#  'Apaixonadas Por Futebol': 'apaixonadasfut',
#  'Igor Reale': 'igorrealequatro',
#  'only feias': 'OKblema',
#  '𝕵𝖍𝖊𝖓𝖓𝖎 🪐': 'Jhenni885',
#  'indio': 'indiobxd',
#  'ayonã': 'Ay0n4',
#  'Linns 🇾🇪': 'H_Linns',
#  'Com amor, frases': 'ComAmorFrases',
#  'ruth💟': 'ruthslaterx',
#  'Clone do Dell ~': 'NQV_B',
#  'TE VI NO TREM / METRO RJ': 'tevinotrem',
#  'Maurício Moura': 'Maumaumo_',
#  'dav¡ #0 KILLUA STAN': 'killstan_',
#  'Lucas Prata Fortes (Caju)': 'lpfortes',
#  '.': '_larasena',
#  'AmorKarioca': 'AmorKarioca',
#  'Arthur do Val - Mamaefalei': 'arthurmoledoval'}

# %% [markdown]
# ### Find existing names in display names

# %% [markdown]
# We generate a list `names_list` of our display names by extracting the keys from our dictionary names_dict. We drop potential duplicates and lowercase the display names.

# %%
#lowercase
names_dict = dict((k.lower(), v) for k,v in names_dict.items())
#drop duplicates
names_list = list(names_dict.keys())
names_list = list(dict.fromkeys(names_list))

# %% [markdown]
# In total, we now have 574 display names.

# %%
len(names_list)
# Out:
# 574

# %% [markdown]
# We now loop through our display names. For each display name, we check whether it contains a first name contained in our database of Brazilian first names and gender. If it does, we assign the related handle to the gender of the matched first name.

# %%
results_dict = dict()
for twitter_name in names_list:
    for num, name in enumerate(names_df['name'].tolist()):
        pattern = re.compile(f"(^|\W){name}(\W|$)")
        if pattern.match(twitter_name):
            print(f'***Display name on Twitter: {twitter_name} ***')
            print(f'Matched first name: {name}')
            print(f"Gender associated with matched first name: {names_df['gender'][num]}")
            handle = names_dict[twitter_name]
            results_dict[handle] = names_df['gender'][num]
# Out:
# ***Display name on Twitter: samuel nascimento💯 ***
# Matched first name: samuel
# Gender associated with matched first name: M
# ***Display name on Twitter: maria oaquim ***
# Matched first name: maria
# Gender associated with matched first name: F
# ***Display name on Twitter: gaby ***
# Matched first name: gaby
# Gender associated with matched first name: F
# ***Display name on Twitter: francisco de laurentiis ***
# Matched first name: francisco
# Gender associated with matched first name: M
# ***Display name on Twitter: lorena⭐️ ***
# Matched first name: lorena
# Gender associated with matched first name: F
# ***Display name on Twitter: isaque morais ***
# Matched first name: isaque
# Gender associated with matched first name: M
# ***Display name on Twitter: vera magalhães vacina já 💉 ***
# Matched first name: vera
# Gender associated with matched first name: F
# ***Display name on Twitter: thomas santana ***
# Matched first name: thomas
# Gender associated with matched first name: M
# ***Display name on Twitter: joice hasselmann ***
# Matched first name: joice
# Gender associated with matched first name: F
# ***Display name on Twitter: bernardo mello franco ***
# Matched first name: bernardo
# Gender associated with matched first name: M
# ***Display name on Twitter: aline lopes ***
# Matched first name: aline
# Gender associated with matched first name: F
# ***Display name on Twitter: gabriela ***
# Matched first name: gabriela
# Gender associated with matched first name: F
# ***Display name on Twitter: clara ***
# Matched first name: clara
# Gender associated with matched first name: F
# ***Display name on Twitter: lucas rangel ***
# Matched first name: lucas
# Gender associated with matched first name: M
# ***Display name on Twitter: joão doria ***
# Matched first name: joão
# Gender associated with matched first name: M
# ***Display name on Twitter: vanessa brasil ***
# Matched first name: vanessa
# Gender associated with matched first name: F
# ***Display name on Twitter: rafaela ***
# Matched first name: rafaela
# Gender associated with matched first name: F
# ***Display name on Twitter: fernando alvarenga ***
# Matched first name: fernando
# Gender associated with matched first name: M
# ***Display name on Twitter: dora ***
# Matched first name: dora
# Gender associated with matched first name: F
# ***Display name on Twitter: davi sabbag ***
# Matched first name: davi
# Gender associated with matched first name: M
# ***Display name on Twitter: gisele ***
# Matched first name: gisele
# Gender associated with matched first name: F
# ***Display name on Twitter: joyce sarti ***
# Matched first name: joyce
# Gender associated with matched first name: F
# ***Display name on Twitter: jean 🇮🇩 ***
# Matched first name: jean
# Gender associated with matched first name: M
# ***Display name on Twitter: felipe santiago 😷🏠 ***
# Matched first name: felipe
# Gender associated with matched first name: M
# ***Display name on Twitter: joice ***
# Matched first name: joice
# Gender associated with matched first name: F
# ***Display name on Twitter: rafael lange #ordemparanormal ***
# Matched first name: rafael
# Gender associated with matched first name: M
# ***Display name on Twitter: felipe prior ***
# Matched first name: felipe
# Gender associated with matched first name: M
# ***Display name on Twitter: ygor costa ***
# Matched first name: ygor
# Gender associated with matched first name: M
# ***Display name on Twitter: fernando ***
# Matched first name: fernando
# Gender associated with matched first name: M
# ***Display name on Twitter: mateus ***
# Matched first name: mateus
# Gender associated with matched first name: M
# ***Display name on Twitter: tom fletcher ***
# Matched first name: tom
# Gender associated with matched first name: M
# ***Display name on Twitter: eudes gomes ***
# Matched first name: eudes
# Gender associated with matched first name: M
# ***Display name on Twitter: caroline-seu jorge.mp3 ***
# Matched first name: caroline
# Gender associated with matched first name: F
# ***Display name on Twitter: anne lottermann ***
# Matched first name: anne
# Gender associated with matched first name: F
# ***Display name on Twitter: tiago scheuer ***
# Matched first name: tiago
# Gender associated with matched first name: M
# ***Display name on Twitter: isabela ***
# Matched first name: isabela
# Gender associated with matched first name: F
# ***Display name on Twitter: maria do rosário ***
# Matched first name: maria
# Gender associated with matched first name: F
# ***Display name on Twitter: eduardo bolsonaro🇧🇷 ***
# Matched first name: eduardo
# Gender associated with matched first name: M
# ***Display name on Twitter: carlos bolsonaro ***
# Matched first name: carlos
# Gender associated with matched first name: M
# ***Display name on Twitter: jair m. bolsonaro ***
# Matched first name: jair
# Gender associated with matched first name: M
# ***Display name on Twitter: ana flor ***
# Matched first name: ana
# Gender associated with matched first name: F
# ***Display name on Twitter: dora figueiredo ***
# Matched first name: dora
# Gender associated with matched first name: F
# ***Display name on Twitter: tamires de paula ***
# Matched first name: tamires
# Gender associated with matched first name: F
# ***Display name on Twitter: sara ***
# Matched first name: sara
# Gender associated with matched first name: F
# ***Display name on Twitter: amy ❥ ***
# Matched first name: amy
# Gender associated with matched first name: F
# ***Display name on Twitter: fernando 🦅 ***
# Matched first name: fernando
# Gender associated with matched first name: M
# ***Display name on Twitter: roberta ***
# Matched first name: roberta
# Gender associated with matched first name: F
# ***Display name on Twitter: bianca ***
# Matched first name: bianca
# Gender associated with matched first name: F
# ***Display name on Twitter: maria rita ***
# Matched first name: maria
# Gender associated with matched first name: F
# ***Display name on Twitter: wesley safadão ***
# Matched first name: wesley
# Gender associated with matched first name: M
# ***Display name on Twitter: mariana ***
# Matched first name: mariana
# Gender associated with matched first name: F
# ***Display name on Twitter: oliveira 🌵 ***
# Matched first name: oliveira
# Gender associated with matched first name: M
# ***Display name on Twitter: luan ***
# Matched first name: luan
# Gender associated with matched first name: M
# ***Display name on Twitter: neymar jr ***
# Matched first name: neymar
# Gender associated with matched first name: M
# ***Display name on Twitter: júnior ***
# Matched first name: júnior
# Gender associated with matched first name: M
# ***Display name on Twitter: clarissa ***
# Matched first name: clarissa
# Gender associated with matched first name: F
# ***Display name on Twitter: juliana ***
# Matched first name: juliana
# Gender associated with matched first name: F
# ***Display name on Twitter: elis amâncio em 🏠 ***
# Matched first name: elis
# Gender associated with matched first name: F
# ***Display name on Twitter: ana paula valadão bessa ***
# Matched first name: ana
# Gender associated with matched first name: F
# ***Display name on Twitter: julieta 🌙 ***
# Matched first name: julieta
# Gender associated with matched first name: F
# ***Display name on Twitter: michele araújo clube turismo ***
# Matched first name: michele
# Gender associated with matched first name: F
# ***Display name on Twitter: suellen ***
# Matched first name: suellen
# Gender associated with matched first name: F
# ***Display name on Twitter: isa✨ ***
# Matched first name: isa
# Gender associated with matched first name: F
# ***Display name on Twitter: arthur weintraub ***
# Matched first name: arthur
# Gender associated with matched first name: M
# ***Display name on Twitter: kamila ***
# Matched first name: kamila
# Gender associated with matched first name: F
# ***Display name on Twitter: murilo ***
# Matched first name: murilo
# Gender associated with matched first name: M
# ***Display name on Twitter: nikolas bottós ***
# Matched first name: nikolas
# Gender associated with matched first name: M
# ***Display name on Twitter: dalila silva ***
# Matched first name: dalila
# Gender associated with matched first name: F
# ***Display name on Twitter: maicon reserva ***
# Matched first name: maicon
# Gender associated with matched first name: M
# ***Display name on Twitter: igor aleixo ***
# Matched first name: igor
# Gender associated with matched first name: M
# ***Display name on Twitter: júlia gomes ***
# Matched first name: júlia
# Gender associated with matched first name: F
# ***Display name on Twitter: nazaré amarga ***
# Matched first name: nazaré
# Gender associated with matched first name: M
# ***Display name on Twitter: luana pandoca 🔮 ***
# Matched first name: luana
# Gender associated with matched first name: F
# ***Display name on Twitter: amanda ***
# Matched first name: amanda
# Gender associated with matched first name: F
# ***Display name on Twitter: sérgio alves🚩 #forabolsonaro ***
# Matched first name: sérgio
# Gender associated with matched first name: M
# ***Display name on Twitter: mari ***
# Matched first name: mari
# Gender associated with matched first name: F
# ***Display name on Twitter: lorena nascimento ***
# Matched first name: lorena
# Gender associated with matched first name: F
# ***Display name on Twitter: sophie kwidsan🇺🇸 ***
# Matched first name: sophie
# Gender associated with matched first name: F
# ***Display name on Twitter: bruno covas ***
# Matched first name: bruno
# Gender associated with matched first name: M
# ***Display name on Twitter: pedro hales ***
# Matched first name: pedro
# Gender associated with matched first name: M
# ***Display name on Twitter: carlos a. m. afonso ***
# Matched first name: carlos
# Gender associated with matched first name: M
# ***Display name on Twitter: janaina paschoal ***
# Matched first name: janaina
# Gender associated with matched first name: F
# ***Display name on Twitter: alexandre shazzam ***
# Matched first name: alexandre
# Gender associated with matched first name: M
# ***Display name on Twitter: ronaldo caiado ***
# Matched first name: ronaldo
# Gender associated with matched first name: M
# ***Display name on Twitter: wilson witzel ***
# Matched first name: wilson
# Gender associated with matched first name: M
# ***Display name on Twitter: modesto carvalhosa ***
# Matched first name: modesto
# Gender associated with matched first name: M
# ***Display name on Twitter: pedro kauan ***
# Matched first name: pedro
# Gender associated with matched first name: M
# ***Display name on Twitter: carla morais ***
# Matched first name: carla
# Gender associated with matched first name: F
# ***Display name on Twitter: carla bartiê ***
# Matched first name: carla
# Gender associated with matched first name: F
# ***Display name on Twitter: carolina saar 🇧🇷🇮🇱🇩🇪 ***
# Matched first name: carolina
# Gender associated with matched first name: F
# ***Display name on Twitter: elis ***
# Matched first name: elis
# Gender associated with matched first name: F
# ***Display name on Twitter: alex ***
# Matched first name: alex
# Gender associated with matched first name: M
# ***Display name on Twitter: matheus ***
# Matched first name: matheus
# Gender associated with matched first name: M
# ***Display name on Twitter: yuri oliveira ***
# Matched first name: yuri
# Gender associated with matched first name: M
# ***Display name on Twitter: beatriz ***
# Matched first name: beatriz
# Gender associated with matched first name: F
# ***Display name on Twitter: isa brun ***
# Matched first name: isa
# Gender associated with matched first name: F
# ***Display name on Twitter: thainá ***
# Matched first name: thainá
# Gender associated with matched first name: F
# ***Display name on Twitter: letícia bortolotti ***
# Matched first name: letícia
# Gender associated with matched first name: F
# ***Display name on Twitter: breno reinert ***
# Matched first name: breno
# Gender associated with matched first name: M
# ***Display name on Twitter: nathalia ***
# Matched first name: nathalia
# Gender associated with matched first name: F
# ***Display name on Twitter: felipe ***
# Matched first name: felipe
# Gender associated with matched first name: M
# ***Display name on Twitter: marlon ***
# Matched first name: marlon
# Gender associated with matched first name: M
# ***Display name on Twitter: marcos almeida ***
# Matched first name: marcos
# Gender associated with matched first name: M
# ***Display name on Twitter: josias teófilo ***
# Matched first name: josias
# Gender associated with matched first name: M
# ***Display name on Twitter: ivete 🇪🇪 ***
# Matched first name: ivete
# Gender associated with matched first name: F
# ***Display name on Twitter: ingrid ***
# Matched first name: ingrid
# Gender associated with matched first name: F
# ***Display name on Twitter: michelle h. ***
# Matched first name: michelle
# Gender associated with matched first name: F
# ***Display name on Twitter: luana🌜 ***
# Matched first name: luana
# Gender associated with matched first name: F
# ***Display name on Twitter: lucas ctm 👽 ***
# Matched first name: lucas
# Gender associated with matched first name: M
# ***Display name on Twitter: felipe neto ***
# Matched first name: felipe
# Gender associated with matched first name: M
# ***Display name on Twitter: lucas ***
# Matched first name: lucas
# Gender associated with matched first name: M
# ***Display name on Twitter: paulo bonfim ***
# Matched first name: paulo
# Gender associated with matched first name: M
# ***Display name on Twitter: maria perplecta ***
# Matched first name: maria
# Gender associated with matched first name: F
# ***Display name on Twitter: alessandro loiola ***
# Matched first name: alessandro
# Gender associated with matched first name: M
# ***Display name on Twitter: filipe ret ***
# Matched first name: filipe
# Gender associated with matched first name: M
# ***Display name on Twitter: yasmin 📍 ***
# Matched first name: yasmin
# Gender associated with matched first name: F
# ***Display name on Twitter: luiza ***
# Matched first name: luiza
# Gender associated with matched first name: F
# ***Display name on Twitter: destiny misses the oa ***
# Matched first name: destiny
# Gender associated with matched first name: F
# ***Display name on Twitter: carol🦋 ***
# Matched first name: carol
# Gender associated with matched first name: F
# ***Display name on Twitter: caroline de toni ***
# Matched first name: caroline
# Gender associated with matched first name: F
# ***Display name on Twitter: júlia ***
# Matched first name: júlia
# Gender associated with matched first name: F
# ***Display name on Twitter: paulo junior ***
# Matched first name: paulo
# Gender associated with matched first name: M
# ***Display name on Twitter: malvina ***
# Matched first name: malvina
# Gender associated with matched first name: F
# ***Display name on Twitter: guilherme fiuza ***
# Matched first name: guilherme
# Gender associated with matched first name: M
# ***Display name on Twitter: marcus ¹³ ᶜᵃᵐ ***
# Matched first name: marcus
# Gender associated with matched first name: M
# ***Display name on Twitter: gabriela 🦋 ***
# Matched first name: gabriela
# Gender associated with matched first name: F
# ***Display name on Twitter: joana dabb ***
# Matched first name: joana
# Gender associated with matched first name: F
# ***Display name on Twitter: alan lopes ***
# Matched first name: alan
# Gender associated with matched first name: M
# ***Display name on Twitter: ron eisele ***
# Matched first name: ron
# Gender associated with matched first name: M
# ***Display name on Twitter: marcelo rubens paiva ***
# Matched first name: marcelo
# Gender associated with matched first name: M
# ***Display name on Twitter: luiz henrique ***
# Matched first name: luiz
# Gender associated with matched first name: M
# ***Display name on Twitter: fernando nisio ***
# Matched first name: fernando
# Gender associated with matched first name: M
# ***Display name on Twitter: kaique ***
# Matched first name: kaique
# Gender associated with matched first name: M
# ***Display name on Twitter: tim maia brasileiro ***
# Matched first name: tim
# Gender associated with matched first name: M
# ***Display name on Twitter: ayla ***
# Matched first name: ayla
# Gender associated with matched first name: F
# ***Display name on Twitter: flávio dino 🇧🇷 ***
# Matched first name: flávio
# Gender associated with matched first name: M
# ***Display name on Twitter: gabriel norberto ***
# Matched first name: gabriel
# Gender associated with matched first name: M
# ***Display name on Twitter: henry darko ***
# Matched first name: henry
# Gender associated with matched first name: M
# ***Display name on Twitter: lia clark ✨ ***
# Matched first name: lia
# Gender associated with matched first name: F
# ***Display name on Twitter: pepita | assistam e ouçam #recruta ***
# Matched first name: pepita
# Gender associated with matched first name: F
# ***Display name on Twitter: nick ***
# Matched first name: nick
# Gender associated with matched first name: M
# ***Display name on Twitter: nemo🇧🇷 ***
# Matched first name: nemo
# Gender associated with matched first name: M
# ***Display name on Twitter: chico - mundinho caio caloteiro ***
# Matched first name: chico
# Gender associated with matched first name: M
# ***Display name on Twitter: maria nas nuvens 📖☁️ ***
# Matched first name: maria
# Gender associated with matched first name: F
# ***Display name on Twitter: joão lucas 🏳️‍🌈🇧🇷 ***
# Matched first name: joão
# Gender associated with matched first name: M
# ***Display name on Twitter: michael clifford ***
# Matched first name: michael
# Gender associated with matched first name: M
# ***Display name on Twitter: gabriel ***
# Matched first name: gabriel
# Gender associated with matched first name: M
# ***Display name on Twitter: maria ***
# Matched first name: maria
# Gender associated with matched first name: F
# ***Display name on Twitter: igor reale ***
# Matched first name: igor
# Gender associated with matched first name: M
# ***Display name on Twitter: ruth💟 ***
# Matched first name: ruth
# Gender associated with matched first name: F
# ***Display name on Twitter: maurício moura ***
# Matched first name: maurício
# Gender associated with matched first name: M
# ***Display name on Twitter: lucas prata fortes (caju) ***
# Matched first name: lucas
# Gender associated with matched first name: M
# ***Display name on Twitter: arthur do val - mamaefalei ***
# Matched first name: arthur
# Gender associated with matched first name: M

# %% [markdown]
# We were able to infer the gender of 153 of our 574 display names. When looking at the first few results, the quality looks good: "samuel nascimento" is rightly classified as male whereas "maria oaquim" is righly classified as female.

# %%
len(results_dict)
# Out:
# 153

# %% [markdown]
# ## Conclusion:

# %% [markdown]
# In this notebook, we learned how to infer the gender of Brazilian Twitter users based on their display names.
#
# While the display name is a valuable information for gender inference, other data sources such as the profile picture, the user description or even the social network of the user could be used. Also, other user demographics could be inferred from these information sources, such as age or whether the Twitter account belongs to an organization or not. If you wish to have further information on Twitter demographic inference, you can have a look at the [M3 GitHub repository](https://github.com/euagendas/m3inference), that allows to predict gender, age, and human-vs-organization status, using both text and image inputs, for tweets in multiple languages.

# %% [markdown]
# ## References:

# %% [markdown]
# Wang, Z., Hale, S., Adelani, D., Grabowicz, P., Hartmann, T., Flöck, F., & Jurgens, D. (2019). Demographic Inference and Representative Population Estimates from Multilingual Social Media Data. In Proceedings of the 2019 World Wide Web Conference.

# %% [markdown]
# Wesslen, R., Nandu, S., Eltayeby, O., Gallicano, T., Levens, S., Jiang, M., & Shaikh, S. (2018, June). Bumper Stickers on the Twitter Highway: Analyzing the Speed and Substance of Profile Changes. In Proceedings of the International AAAI Conference on Web and Social Media (Vol. 12, No. 1).
